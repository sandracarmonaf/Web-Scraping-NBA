# %%
# ======================= Importación de Librerías =======================
import csv
import json
import random
import re
import time
from IPython.display import Image  # Mostrar imágenes en entornos interactivos (opcional)
from selenium import webdriver  # Automatización del navegador
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager  # Gestor automático de drivers

# ======================= Configuración del Navegador =======================
options = Options()
options.add_argument('--headless')  # Ejecutar en modo sin interfaz gráfica
options.add_argument('--no-sandbox')  # Evitar errores de usuario en entornos restringidos
options.add_argument('--disable-dev-shm-usage')  # Incrementa memoria compartida en contenedores

# ======================= Inicialización del Navegador =======================
browser = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
browser.maximize_window()  # Maximizar la ventana del navegador al abrir

# %%
# ======================= Función para Mostrar Captura de Pantalla =======================
def show_screenshot(browser, fuente):
    """
    Guarda una captura de pantalla del navegador y la muestra.

    Parameters:
    - browser (webdriver): instancia del navegador Selenium
    - fuente (str): nombre de la fuente, usado para el archivo de imagen

    Returns:
    - Image: visualización de la captura de pantalla en el entorno interactivo
    """
    # Definir el nombre del archivo y la ruta donde se guardará
    path_png = f'./imgs/{fuente}.png'
    
    # Guardar la captura de pantalla en el archivo especificado
    browser.save_screenshot(path_png)
    
    # Mostrar la captura de pantalla guardada
    return Image(path_png)

# %%
# ======================= Función para Realizar Búsqueda =======================
def search_data(browser):
    """
    Realiza una búsqueda en la página web usando el término de entrada en el campo de búsqueda.

    Parameters:
    - inp_search (str): término a buscar (ej. 'Barcelona')
    - browser (webdriver): instancia del navegador de Selenium

    Returns:
    - None
    """

    # Insertar el término de búsqueda en el campo correspondiente
    id_input = 'header_leagues'
    e_input = browser.find_element(By.ID, id_input)
    e_input.click()
    # Confirmación de búsqueda realizada
    print(f'==> Se buscaron los datos para')

# %%
# ======================= Función para Guardar Registros de la Página =======================
def save_records_from_page(browser, list_dict):
    links = browser.find_elements(By.XPATH, '//tr[@class="thead"]/following-sibling::tr/th[@scope="row"]/a')

    for index, link in enumerate(links):
        url = link.get_attribute("href")  # Obtiene la URL del enlace
        print(f"Abriendo: {url}")

        # Abrir el enlace en una nueva pestaña
        browser.execute_script(f"window.open('{url}', '_blank');")
        time.sleep(2)  # Esperar un poco para que la página cargue

        # Cambiar a la nueva pestaña
        browser.switch_to.window(browser.window_handles[-1])
        time.sleep(2)
        e_input = browser.find_element(By.XPATH, '//ul[@class="hoversmooth"]/li[3]')
        e_input.click()
        time.sleep(2)  # Esperar un poco más para evitar errores de carga
        
        # Capturar pantalla
        show_screenshot(browser, f"pagina_{index}")

        links2 = browser.find_elements(By.XPATH, '//div[@class="filter"]/div/a')

        for index2, link2 in enumerate(links2):
            url2 = link2.get_attribute("href")  # Obtiene la URL del enlace
            print(f"Abriendo: {url2}")

            # Abrir el enlace en una nueva pestaña
            browser.execute_script(f"window.open('{url2}', '_blank');")
            time.sleep(2)  # Esperar un poco para que la página cargue

            # Cambiar a la nueva pestaña
            browser.switch_to.window(browser.window_handles[-1])

            try:
                body = browser.find_element(By.TAG_NAME, 'body')
                body.send_keys(Keys.ESCAPE)
                time.sleep(2)  # Espera un poco para asegurarse de que se cierre
            except Exception as e:
                print("No se pudo cerrar con Esc:", e)


            time.sleep(2)
            # Capturar pantalla
            show_screenshot(browser, f"pagina_{index}_{index2}")

            links3 = browser.find_elements(By.XPATH,'//div[@id="all_schedule"]//table//td[6]/a')

            for index3, link3 in enumerate(links3):
                url3 = link3.get_attribute("href")  # Obtiene la URL del enlace
                print(f"Abriendo: {url3}")

                # Abrir el enlace en una nueva pestaña
                browser.execute_script(f"window.open('{url3}', '_blank');")
                time.sleep(2)  # Esperar un poco para que la página cargue

                # Cambiar a la nueva pestaña
                browser.switch_to.window(browser.window_handles[-1])

                # Capturar pantalla
                show_screenshot(browser, f"pagina_{index}_{index2}_{index3}")
        
                # Cerrar la pestaña actual
                browser.close()
                time.sleep(1)
                browser.switch_to.window(browser.window_handles[2])

            # Cerrar la pestaña actual
            browser.close()
            time.sleep(1)
            browser.switch_to.window(browser.window_handles[1])
        
        # Cerrar la pestaña actual
        browser.close()
        time.sleep(1)

        # Solo cambiar de pestaña si aún hay pestañas abiertas
        if len(browser.window_handles) > 0:
            browser.switch_to.window(browser.window_handles[0])

# %%
# ============================ Ejecución Principal ===============================

# 1. Parámetros
url_root = 'https://www.basketball-reference.com/'

# 2. Navegar a la página principal
browser.get(url_root)
show_screenshot(browser, "0. Pagina Principal")

# 3. Realizar la búsqueda
search_data(browser)
show_screenshot(browser, "1. Pagina Temporadas")

# 4. Extraer y guardar registros de la página
time.sleep(1)  # Esperar antes de iniciar la extracción

list_dict = []  # Lista vacía si necesitas almacenar información extra
save_records_from_page(browser, list_dict)

# 5. Cerrar el navegador
browser.quit()
# Out:
# ==> Se buscaron los datos para
# Abriendo: https://www.basketball-reference.com/leagues/NBA_2025.html
# Abriendo: https://www.basketball-reference.com/leagues/NBA_2025_games-october.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410220BOS.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410220LAL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410230DET.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410230ATL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410230MIA.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410230PHI.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410230TOR.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410230HOU.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410230NOP.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410230UTA.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410230LAC.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410230POR.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410240WAS.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410240DAL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410240SAC.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410240DEN.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410250ORL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410250TOR.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410250ATL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410250CLE.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410250NYK.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410250HOU.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410250MIL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410250UTA.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410250LAL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410250POR.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410260DEN.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410260WAS.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410260DET.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410260CHO.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410260MEM.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410260MIN.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410260CHI.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410260SAS.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410260PHO.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410260LAL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410270IND.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410270POR.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410270BRK.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410270OKC.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410270GSW.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410280ORL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410280ATL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410280BOS.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410280TOR.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410280MIA.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410280NYK.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410280SAS.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410280MEM.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410280DAL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410280SAC.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410280PHO.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410290BRK.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410290MIN.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410290UTA.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410290GSW.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410300PHI.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410300WAS.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410300IND.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410300CLE.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410300CHO.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410300MIA.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410300CHI.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410300MEM.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410300OKC.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410300GSW.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410300LAC.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410310MEM.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410310DAL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410310UTA.html
# Abriendo: https://www.basketball-reference.com/boxscores/202410310LAC.html
# Abriendo: https://www.basketball-reference.com/leagues/NBA_2025_games-november.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411010CHO.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411010CLE.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411010DET.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411010ATL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411010BRK.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411010TOR.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411010NOP.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411010MIN.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411010POR.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411020CHO.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411020PHI.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411020TOR.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411020HOU.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411020MIL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411020SAS.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411020WAS.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411020DEN.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411020PHO.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411020LAC.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411030BRK.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411030NOP.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411030DAL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040CLE.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040WAS.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040DET.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040ATL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040BRK.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040MIA.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040CHI.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040HOU.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040MIN.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040OKC.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040NOP.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040DAL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040DEN.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040PHO.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411040LAC.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411060CHO.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411060IND.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411060ATL.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411060BOS.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411060HOU.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411060MEM.html
# Abriendo: https://www.basketball-reference.com/boxscores/202411060NOP.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[248], line 18
#      15 time.sleep(1)  # Esperar antes de iniciar la extracción
#      17 list_dict = []  # Lista vacía si necesitas almacenar información extra
# ---> 18 save_records_from_page(browser, list_dict)
#      20 # 5. Cerrar el navegador
#      21 browser.quit()
#
# Cell In[247], line 62, in save_records_from_page(browser, list_dict)
#      59 browser.switch_to.window(browser.window_handles[-1])
#      61 # Capturar pantalla
# ---> 62 show_screenshot(browser, f"pagina_{index}_{index2}_{index3}")
#      64 # Cerrar la pestaña actual
#      65 browser.close()
#
# Cell In[245], line 17, in show_screenshot(browser, fuente)
#      14 path_png = f'./imgs/{fuente}.png'
#      16 # Guardar la captura de pantalla en el archivo especificado
# ---> 17 browser.save_screenshot(path_png)
#      19 # Mostrar la captura de pantalla guardada
#      20 return Image(path_png)
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:994, in WebDriver.save_screenshot(self, filename)
#     979 def save_screenshot(self, filename) -> bool:
#     980     """Saves a screenshot of the current window to a PNG image file.
#     981     Returns False if there is any IOError, else returns True. Use full
#     982     paths in your filename.
#    (...)
#     992     >>> driver.save_screenshot('/Screenshots/foo.png')
#     993     """
# --> 994     return self.get_screenshot_as_file(filename)
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:969, in WebDriver.get_screenshot_as_file(self, filename)
#     963 if not str(filename).lower().endswith(".png"):
#     964     warnings.warn(
#     965         "name used for saved screenshot does not match file type. It should end with a `.png` extension",
#     966         UserWarning,
#     967         stacklevel=2,
#     968     )
# --> 969 png = self.get_screenshot_as_png()
#     970 try:
#     971     with open(filename, "wb") as f:
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:1003, in WebDriver.get_screenshot_as_png(self)
#     996 def get_screenshot_as_png(self) -> bytes:
#     997     """Gets the screenshot of the current window as a binary data.
#     998
#     999     Example:
#    1000     --------
#    1001     >>> driver.get_screenshot_as_png()
#    1002     """
# -> 1003     return b64decode(self.get_screenshot_as_base64().encode("ascii"))
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:1013, in WebDriver.get_screenshot_as_base64(self)
#    1005 def get_screenshot_as_base64(self) -> str:
#    1006     """Gets the screenshot of the current window as a base64 encoded string
#    1007     which is useful in embedded images in HTML.
#    1008
#    (...)
#    1011     >>> driver.get_screenshot_as_base64()
#    1012     """
# -> 1013     return self.execute(Command.SCREENSHOT)["value"]
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:427, in WebDriver.execute(self, driver_command, params)
#     424     elif "sessionId" not in params:
#     425         params["sessionId"] = self.session_id
# --> 427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
#     429     self.error_handler.check_response(response)
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/selenium/webdriver/remote/remote_connection.py:404, in RemoteConnection.execute(self, command, params)
#     402 trimmed = self._trim_large_entries(params)
#     403 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404 return self._request(command_info[0], url, body=data)
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/selenium/webdriver/remote/remote_connection.py:428, in RemoteConnection._request(self, method, url, body)
#     425     body = None
#     427 if self._client_config.keep_alive:
# --> 428     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429     statuscode = response.status
#     430 else:
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/urllib3/_request_methods.py:135, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     132     urlopen_kw["body"] = body
#     134 if method in self._encode_url_methods:
# --> 135     return self.request_encode_url(
#     136         method,
#     137         url,
#     138         fields=fields,  # type: ignore[arg-type]
#     139         headers=headers,
#     140         **urlopen_kw,
#     141     )
#     142 else:
#     143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/urllib3/_request_methods.py:182, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#     179 if fields:
#     180     url += "?" + urlencode(fields)
# --> 182 return self.urlopen(method, url, **extra_kw)
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Desktop/WebScraping/env/lib/python3.12/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:
